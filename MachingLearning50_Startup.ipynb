# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenMinhThangNMT/HomeWorks/blob/main/MachingLearning50_Startup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url='50_Startups.csv'
data=pd.read_csv(url)
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
correlation =data.corr()
print(correlation)
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
from sklearn import linear_model
model=linear_model.LinearRegression()
X= pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2]).T
model.fit(X,y=data['Profit'])
print('Intercept cua mon hinh',model.intercept_)
print('Coffient cua mo hinh',model.coef_)
print('Do chinh xac cua mo hinh',model.score(X,y=data['Profit']))
# Out:
# Intercept cua mon hinh 48128.14916956878
# Coffient cua mo hinh [ 8.90147291e-01 -2.31821806e-07]
# Do chinh xac cua mo hinh 0.946703652909133

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2]).T
model.fit(X,y=data['Profit'])
print('Intercept của mô hình',model.intercept_)
print('Coeffient của mô hình',model.coef_)
print('Độ chính xác của mô hình',model.score(X,y=data['Profit']))

range = np.arange(data['R&D Spend'].min(),data['R&D Spend'].max(),10)
data.plot(kind='scatter',x ='R&D Spend',y='Profit',figsize=(12,12),color='black',xlim=(data['R&D Spend'].min(),data['R&D Spend'].max()))
predictor = pd.DataFrame([range,range**2]).T
y_pred = model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept của mô hình 48128.14916956878
# Coeffient của mô hình [ 8.90147291e-01 -2.31821806e-07]
# Độ chính xác của mô hình 0.946703652909133
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3]).T
model.fit(X,y=data['Profit'])
print('Intercept của mô hình',model.intercept_)
print('Coeffient của mô hình',model.coef_)
print('Độ chính xác của mô hình',model.score(X,y=data['Profit']))

range = np.arange(data['R&D Spend'].min(),data['R&D Spend'].max(),10)
data.plot(kind='scatter',x ='R&D Spend',y='Profit',figsize=(12,12),color='black',xlim=(data['R&D Spend'].min(),data['R&D Spend'].max()))
predictor = pd.DataFrame([range,range**2,range**3]).T
y_pred = model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept của mô hình 43108.76756818297
# Coeffient của mô hình [ 1.40072682e+00 -8.82403324e-06  3.64774030e-11]
# Độ chính xác của mô hình 0.9540709421464032
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
