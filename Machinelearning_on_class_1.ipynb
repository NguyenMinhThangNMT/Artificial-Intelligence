# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenMinhThangNMT/HomeWorks/blob/main/Machinelearning_on_class_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url='mtcars.csv'
data=pd.read_csv(url)
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
correlation =data.corr()
print(correlation)
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation,annot=True)
# Out:
# <AxesSubplot:>

# %%
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black')
# Out:
# <AxesSubplot:xlabel='wt', ylabel='mpg'>

# %%
#su dung thu vien 
from sklearn import linear_model
model=linear_model.LinearRegression()
#Ham day hoc
model.fit(X=pd.DataFrame(data['wt']),y=data['mpg'])
print(model.intercept_)
print(model.coef_)
# Out:
# 37.28512616734204
# [-5.34447157]

# %%
#Do chinh xac
model.score(X=pd.DataFrame(data['wt']),y=data['mpg'])
# Out:
# 0.7528327936582646

# %%
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
y_pred=model.predict(X=pd.DataFrame(data['wt']))
plt.plot(data['wt'],y_pred,color='blue')

# %%
model=linear_model.LinearRegression()
X= pd.DataFrame([data['wt'],data['wt']**2]).T
model.fit(X,y=data['mpg'])
print('Intercept cua mon hinh',model.intercept_)
print('Coffient cua mo hinh',model.coef_)
print('Do chinh xac cua mo hinh',model.score(X,y=data['mpg']))
# Out:
# Intercept cua mon hinh 49.93081094945181
# Coffient cua mo hinh [-13.38033708   1.17108689]
# Do chinh xac cua mo hinh 0.8190613581384094

# %%
import numpy as np
range=np.arange(1.5,55,0.1)

predictor=pd.DataFrame([range,range**2]).T
y_pred=model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
model=linear_model.LinearRegression()
X= pd.DataFrame([data['wt'],data['wt']**3]).T
model.fit(X,y=data['mpg'])
print('Intercept cua mon hinh',model.intercept_)
print('Coffient cua mo hinh',model.coef_)
print('Do chinh xac cua mo hinh',model.score(X,y=data['mpg']))
import numpy as np
range=np.arange(1.5,5.5,0.1)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
predictor=pd.DataFrame([range,range**3]).T
y_pred=model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept cua mon hinh 46.18691542897024
# Coffient cua mo hinh [-9.58658863  0.1112848 ]
# Do chinh xac cua mo hinh 0.8189918444632485
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
model=linear_model.LinearRegression()
X= pd.DataFrame([data['wt'],data['wt']**5]).T
model.fit(X,y=data['mpg'])
print('Intercept cua mon hinh',model.intercept_)
print('Coffient cua mo hinh',model.coef_)
print('Do chinh xac cua mo hinh',model.score(X,y=data['mpg']))
import numpy as np
range=np.arange(1.5,5.5,0.1)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
predictor=pd.DataFrame([range,range**5]).T
y_pred=model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept cua mon hinh 43.36121960046691
# Coffient cua mo hinh [-7.76733717e+00  2.31835970e-03]
# Do chinh xac cua mo hinh 0.8169282455035884
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Tạo ra mô hình mới bậc 10
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9,data['wt']**10]).T
model.fit(X,y=data['mpg'])
print('Intercept của mô hình',model.intercept_)
print('Coeffient của mô hình',model.coef_)
print('Độ chính xác của mô hình',model.score(X,y=data['mpg']))

range = np.arange(1.5,5.5,0.1)
data.plot(kind='scatter',x ='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
predictor = pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T
y_pred = model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept của mô hình -14921.11995188375
# Coeffient của mô hình [ 6.45813558e+04 -1.20086131e+05  1.26931928e+05 -8.46598454e+04
#   3.73155199e+04 -1.10334755e+04  2.16590404e+03 -2.70730544e+02
#   1.94974162e+01 -6.15515436e-01]
# Độ chính xác của mô hình 0.8702106571479111
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
model=linear_model.LinearRegression()
X= pd.DataFrame([data['wt'],data['wt']**25]).T
model.fit(X,y=data['mpg'])
print('Intercept cua mon hinh',model.intercept_)
print('Coffient cua mo hinh',model.coef_)
print('Do chinh xac cua mo hinh',model.score(X,y=data['mpg']))
import numpy as np
range=np.arange(1.5,5.5,0.1)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
predictor=pd.DataFrame([range,range**25]).T
y_pred=model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept cua mon hinh 20.862399012184955
# Coffient cua mo hinh [-6.64130423e-36 -5.06808300e-18]
# Do chinh xac cua mo hinh 0.18186704009428134
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
model=linear_model.LinearRegression()
model.fit(X=data.loc[:, ['wt','hp']],y=data['mpg'])
print('Intercept của mô hình',model.intercept_)
print('Coeffient của mô hình',model.coef_)
print('Độ chính xác của mô hình',model.score(X=data.loc[:, ['wt','hp']],y=data['mpg']))
# Out:
# Intercept của mô hình 37.227270116447215
# Coeffient của mô hình [-3.87783074 -0.03177295]
# Độ chính xác của mô hình 0.8267854518827914
