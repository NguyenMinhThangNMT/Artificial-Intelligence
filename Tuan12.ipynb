# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenMinhThangNMT/HomeWorks/blob/main/Tuan12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 28.0 MB/s eta 0:00:00
# ...

# %%
pip install facenet-pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 26.0 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
from  mtcnn import MTCNN
filename ='/content/Chexanh.jpg'
img = plt.imread(filename)
detector=MTCNN()
faces=detector.detect_faces(img)
for face in faces :
   print(face)
plt.imshow(img)
# Out:
# ...
# 7/7 [==============================] - 0s 26ms/step
# {'box': [848, 249, 40, 51], 'confidence': 1.0, 'keypoints': {'left_eye': (860, 268), 'right_eye': (877, 268), 'nose': (869, 279), 'mouth_left': (859, 285), 'mouth_right': (878, 285)}}
# {'box': [445, 262, 38, 48], 'confidence': 0.9999998807907104, 'keypoints': {'left_eye': (454, 281), 'right_eye': (472, 281), 'nose': (463, 293), 'mouth_left': (454, 297), 'mouth_right': (472, 297)}}
# {'box': [318, 248, 42, 57], 'confidence': 0.9999984502792358, 'keypoints': {'left_eye': (330, 269), 'right_eye': (349, 268), 'nose': (340, 281), 'mouth_left': (330, 290), 'mouth_right': (349, 290)}}
# {'box': [661, 136, 37, 51], 'confidence': 0.9999881982803345, 'keypoints': {'left_eye': (671, 154), 'right_eye': (689, 155), 'nose': (680, 164), 'mouth_left': (672, 174), 'mouth_right': (686, 175)}}
# ...

# %%
import matplotlib.pyplot as plt
from  mtcnn import MTCNN
filename ='/content/2.jpg'
img = plt.imread(filename)
detector=MTCNN()
faces=detector.detect_faces(img)
for face in faces :
   print(face)
plt.imshow(img)
ax=plt.gca()
for face in faces:
  x,y,width,height=face['box']
  rect=plt.Rectangle((x,y),width,height,fill=False,color='red')
  ax.add_patch(rect)
  plt.axis('off')
  #plt.savefig('/content/drive/MyDrive/Mon AI/Codongvienvienvietnam.jpg')
for key,value in face['keypoints'].items():
  dot=plt.Circle(value,radius=2,color='red')
  ax.add_patch(dot)
plt.show()
# Out:
# ...
# 24/24 [==============================] - 0s 3ms/step
# {'box': [416, 481, 17, 21], 'confidence': 0.9999953508377075, 'keypoints': {'left_eye': (421, 490), 'right_eye': (429, 488), 'nose': (426, 493), 'mouth_left': (423, 498), 'mouth_right': (430, 497)}}
# {'box': [185, 484, 20, 26], 'confidence': 0.9999923706054688, 'keypoints': {'left_eye': (191, 495), 'right_eye': (201, 494), 'nose': (197, 499), 'mouth_left': (193, 505), 'mouth_right': (200, 505)}}
# {'box': [399, 285, 13, 15], 'confidence': 0.9999908208847046, 'keypoints': {'left_eye': (403, 291), 'right_eye': (409, 291), 'nose': (406, 293), 'mouth_left': (403, 297), 'mouth_right': (409, 297)}}
# {'box': [287, 503, 18, 24], 'confidence': 0.9999871253967285, 'keypoints': {'left_eye': (292, 514), 'right_eye': (301, 513), 'nose': (297, 517), 'mouth_left': (294, 522), 'mouth_right': (301, 521)}}
# ...

# %%
import matplotlib.pyplot as plt
from  mtcnn import MTCNN
filename ='/content/Deo-Khau-Trang-2.jpg'
img = plt.imread(filename)
detector=MTCNN()
faces=detector.detect_faces(img)
for face in faces :
   print(face)
plt.imshow(img)
ax=plt.gca()
for face in faces:
  x,y,width,height=face['box']
  rect=plt.Rectangle((x,y),width,height,fill=False,color='red')
  ax.add_patch(rect)
  plt.axis('off')
  #plt.savefig('/content/drive/MyDrive/Mon AI/Codongvienvienvietnam.jpg')
  for key,value in face['keypoints'].items():
    dot=plt.Circle(value,radius=2,color='red')
    ax.add_patch(dot)
plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 135ms/step
# {'box': [1041, 278, 117, 149], 'confidence': 0.9997640252113342, 'keypoints': {'left_eye': (1072, 341), 'right_eye': (1127, 337), 'nose': (1102, 372), 'mouth_left': (1087, 397), 'mouth_right': (1123, 394)}}
# {'box': [608, 352, 121, 157], 'confidence': 0.9997020363807678, 'keypoints': {'left_eye': (647, 417), 'right_eye': (698, 422), 'nose': (673, 462), 'mouth_left': (652, 481), 'mouth_right': (691, 482)}}
# {'box': [659, 112, 118, 137], 'confidence': 0.9990116357803345, 'keypoints': {'left_eye': (695, 165), 'right_eye': (746, 166), 'nose': (724, 192), 'mouth_left': (705, 217), 'mouth_right': (745, 215)}}
# {'box': [829, 243, 151, 189], 'confidence': 0.9980744123458862, 'keypoints': {'left_eye': (881, 337), 'right_eye': (942, 321), 'nose': (928, 378), 'mouth_left': (899, 405), 'mouth_right': (940, 394)}}
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
def draw_faces(filename,result_list):
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1,width,height = result_list[i]['box']
    x2,y2 = x1 + width,y1 + height
    plt.subplot(1,len(result_list),i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
  plt.show()
filename='/content/Chexanh.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
draw_faces(filename,faces)
# Out:
# ...
# 7/7 [==============================] - 0s 3ms/step

# %%
pip install keras-resnet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for keras-resnet: filename=keras_resnet-0.2.0-py2.py3-none-any.whl size=20484 sha256=739cd5a124cc031f70d5ac53d9eea21c63554ec7b199c750b3df370315030b24
#   Stored in directory: /root/.cache/pip/wheels/53/ed/ef/144804f160c278c80d6429c97ed126b61276721894ce64cccc
# Successfully built keras-resnet
# ...

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from keras.utils import load_img,img_to_array
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/content/chu-cho.jpg'
img = load_img(img_path, target_size=(224, 224))
x = img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
img = plt.imread(img_path)
plt.show()

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# 1/1 [==============================] - 1s 851ms/step
# Predicted: [('n02110063', 'malamute', 0.48853102), ('n02109961', 'Eskimo_dog', 0.32879755), ('n02110185', 'Siberian_husky', 0.070981495)]
